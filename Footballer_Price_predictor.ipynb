# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning and Manipulation

# %%
df=pd.read_csv("players.csv",low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0            Name        Position  Age  \
# 0           0   Kylian Mbappé  Centre-Forward   22
# 1           1  Erling Haaland  Centre-Forward   21
# 2           2      Harry Kane  Centre-Forward   28
# 3           3   Jack Grealish     Left Winger   26
# 4           4   Mohamed Salah    Right Winger   29
#
#    Markey Value In Millions(£)  Country                 Club  Matches  Goals  \
# 0                        144.0   France  Paris Saint-Germain       16      7
# 1                        135.0   Norway    Borussia Dortmund       10     13
# 2                        108.0  England    Tottenham Hotspur       16      7
# 3                         90.0  England      Manchester City       15      2
# 4                         90.0    Egypt         Liverpool FC       15     15
#
#    Own Goals  Assists  Yellow Cards  Second Yellow Cards  Red Cards  \
# 0          0       11             3                    0          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   500 non-null    int64
#  1   Name                         500 non-null    object
#  2   Position                     500 non-null    object
#  3   Age                          500 non-null    int64
#  4   Markey Value In Millions(£)  500 non-null    float64
#  5   Country                      500 non-null    object
#  6   Club                         500 non-null    object
#  7   Matches                      500 non-null    int64
#  8   Goals                        500 non-null    int64
#  9   Own Goals                    500 non-null    int64
#  10  Assists                      500 non-null    int64
#  11  Yellow Cards                 500 non-null    int64
#  12  Second Yellow Cards          500 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# Name                           0
# Position                       0
# Age                            0
# Markey Value In Millions(£)    0
# Country                        0
# Club                           0
# Matches                        0
# Goals                          0
# Own Goals                      0
# Assists                        0
# Yellow Cards                   0
# Second Yellow Cards            0
# Red Cards                      0
# Number Of Substitute In        0
# Number Of Substitute Out       0
# dtype: int64

# %%
df=df.rename(columns={'Markey Value In Millions(£)':'market_value'})

# %%
df.describe()
# Out:
#        Unnamed: 0         Age  market_value     Matches       Goals  \
# count  500.000000  500.000000    500.000000  500.000000  500.000000
# mean   249.500000   24.968000     31.537800   12.396000    2.160000
# std    144.481833    3.165916     17.577697    4.342453    2.880102
# min      0.000000   16.000000     16.200000    0.000000    0.000000
# 25%    124.750000   23.000000     19.800000   10.000000    0.000000
# 50%    249.500000   25.000000     25.200000   13.000000    1.000000
# 75%    374.250000   27.000000     36.000000   16.000000    3.000000
# max    499.000000   36.000000    144.000000   24.000000   23.000000
#
#         Own Goals    Assists  Yellow Cards  Second Yellow Cards   Red Cards  \
# count  500.000000  500.00000    500.000000           500.000000  500.000000
# mean     0.030000    1.51200      1.592000             0.036000    0.046000
# std      0.170758    1.85276      1.445585             0.186477    0.209695
# ...

# %%
fig,ax=plt.subplots(figsize=(10,8))
ax.hist(df['market_value'])
plt.xlabel("Market Values")
plt.ylabel("Frequency")
plt.title("How players distributed respect to Market Value")
# Out:
# Text(0.5, 1.0, 'How players distributed respect to Market Value')

# %%
df.head()
# Out:
#    Unnamed: 0            Name        Position  Age  market_value  Country  \
# 0           0   Kylian Mbappé  Centre-Forward   22         144.0   France
# 1           1  Erling Haaland  Centre-Forward   21         135.0   Norway
# 2           2      Harry Kane  Centre-Forward   28         108.0  England
# 3           3   Jack Grealish     Left Winger   26          90.0  England
# 4           4   Mohamed Salah    Right Winger   29          90.0    Egypt
#
#                   Club  Matches  Goals  Own Goals  Assists  Yellow Cards  \
# 0  Paris Saint-Germain       16      7          0       11             3
# 1    Borussia Dortmund       10     13          0        4             1
# 2    Tottenham Hotspur       16      7          0        2             2
# 3      Manchester City       15      2          0        3             1
# 4         Liverpool FC       15     15          0        6             1
#
#    Second Yellow Cards  Red Cards  Number Of Substitute In  \
# ...

# %%
fig,ax=plt.subplots(figsize=(10,6))
ax.scatter(df['Goals'],df['market_value'])
plt.xlabel('goals scored by players this season')
plt.ylabel('Market Values')
# Out:
# Text(0, 0.5, 'Market Values')

# %%
fig,ax=plt.subplots(figsize=(10,6))
ax.scatter(df['Assists'],df['market_value'])
plt.xlabel(' Assists  by players this season')
plt.ylabel('Market Values')
# Out:
# Text(0, 0.5, 'Market Values')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#              Name        Position  Age  market_value  Country  \
# 0   Kylian Mbappé  Centre-Forward   22         144.0   France
# 1  Erling Haaland  Centre-Forward   21         135.0   Norway
# 2      Harry Kane  Centre-Forward   28         108.0  England
# 3   Jack Grealish     Left Winger   26          90.0  England
# 4   Mohamed Salah    Right Winger   29          90.0    Egypt
#
#                   Club  Matches  Goals  Own Goals  Assists  Yellow Cards  \
# 0  Paris Saint-Germain       16      7          0       11             3
# 1    Borussia Dortmund       10     13          0        4             1
# 2    Tottenham Hotspur       16      7          0        2             2
# 3      Manchester City       15      2          0        3             1
# 4         Liverpool FC       15     15          0        6             1
#
#    Second Yellow Cards  Red Cards  Number Of Substitute In  \
# 0                    0          0                        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      500 non-null    object
#  1   Position                  500 non-null    object
#  2   Age                       500 non-null    int64
#  3   market_value              500 non-null    float64
#  4   Country                   500 non-null    object
#  5   Club                      500 non-null    object
#  6   Matches                   500 non-null    int64
#  7   Goals                     500 non-null    int64
#  8   Own Goals                 500 non-null    int64
#  9   Assists                   500 non-null    int64
#  10  Yellow Cards              500 non-null    int64
#  11  Second Yellow Cards       500 non-null    int64
#  12  Red Cards                 500 non-null    int64
#  13  Number Of Substitute In   500 non-null    int64
# ...

# %%
for label,content in df.items():
    if not pd.api.types.is_numeric_dtype(content):
           df[label]=content.astype("category").cat.as_ordered()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      500 non-null    category
#  1   Position                  500 non-null    category
#  2   Age                       500 non-null    int64
#  3   market_value              500 non-null    float64
#  4   Country                   500 non-null    category
#  5   Club                      500 non-null    category
#  6   Matches                   500 non-null    int64
#  7   Goals                     500 non-null    int64
#  8   Own Goals                 500 non-null    int64
#  9   Assists                   500 non-null    int64
#  10  Yellow Cards              500 non-null    int64
#  11  Second Yellow Cards       500 non-null    int64
#  12  Red Cards                 500 non-null    int64
# ...

# %%
df.Name.cat.categories
# Out:
# Index(['Aaron Ramsdale', 'Aaron Wan-Bissaka', 'Abdou Diallo',
#        'Abdoulaye Doucouré', 'Achraf Hakimi', 'Adam Armstrong', 'Adama Traoré',
#        'Adrien Rabiot', 'Alejandro Grimaldo', 'Aleksandr Golovin',
#        ...
#        'Yusuf Yazici', 'Yves Bissouma', 'Yéremy Pino', 'Zeki Celik',
#        'Álex Remiro', 'Álvaro Morata', 'Ángel Correa', 'Ángel Di María',
#        'Éder Militão', 'Éverton'],
#       dtype='object', length=500)

# %%
df.Name.cat.codes
# Out:
# 0      255
# 1      132
# 2      173
# 3      191
# 4      329
#       ...
# 495    162
# 496     48
# 497     13
# 498    112
# 499     41
# Length: 500, dtype: int16

# %%
cat_uniques = {
    label: df[label].nunique()
    for label, content in df.items()
    if not pd.api.types.is_numeric_dtype(content)
}


cat_uniques_df = pd.DataFrame(list(cat_uniques.items()), columns=["Column", "Unique Count"])
print(cat_uniques_df)
# Out:
#      Column  Unique Count
# 0      Name           500
# 1  Position            13
# 2   Country            57
# 3      Club            81

# %%
df_tmp=df.copy()

# %%
df_tmp
# Out:
#                        Name            Position  Age  market_value  Country  \
# 0             Kylian Mbappé      Centre-Forward   22         144.0   France
# 1            Erling Haaland      Centre-Forward   21         135.0   Norway
# 2                Harry Kane      Centre-Forward   28         108.0  England
# 3             Jack Grealish         Left Winger   26          90.0  England
# 4             Mohamed Salah        Right Winger   29          90.0    Egypt
# ..                      ...                 ...  ...           ...      ...
# 495  Giorgian de Arrascaeta  Attacking Midfield   27          16.2  Uruguay
# 496             Ayoze Pérez      Second Striker   28          16.2    Spain
# 497              Alex Meret          Goalkeeper   24          16.2    Italy
# 498         Duje Caleta-Car         Centre-Back   25          16.2  Croatia
# 499         Aritz Elustondo         Centre-Back   27          16.2    Spain
#
# ...

# %%
df_tmp=df_tmp.drop('Name',axis=1)

# %%
df_tmp.shape,df.shape
# Out:
# ((500, 14), (500, 15))

# %%
counts=df['Club'].value_counts()

# %%
plt.figure(figsize=(10, 20)) 
sns.barplot(x=counts.values, y=counts.index)  
plt.xlabel("Kaç tane")
plt.ylabel("Club ismi")
plt.title("oyuncuların kuluplere dağılımı")
plt.tight_layout()
plt.show()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Position                  500 non-null    category
#  1   Age                       500 non-null    int64
#  2   market_value              500 non-null    float64
#  3   Country                   500 non-null    category
#  4   Club                      500 non-null    category
#  5   Matches                   500 non-null    int64
#  6   Goals                     500 non-null    int64
#  7   Own Goals                 500 non-null    int64
#  8   Assists                   500 non-null    int64
#  9   Yellow Cards              500 non-null    int64
#  10  Second Yellow Cards       500 non-null    int64
#  11  Red Cards                 500 non-null    int64
#  12  Number Of Substitute In   500 non-null    int64
# ...

# %%
column_name = 'Club' 
threshold = 7  

df_tmp[column_name] = df_tmp[column_name].astype(str)


value_counts = df_tmp[column_name].value_counts()


to_replace = value_counts[value_counts < threshold].index


df_tmp[column_name] = df_tmp[column_name].replace(to_replace, 'Other')


print(df_tmp[column_name].value_counts())
# Out:
# Club
# Other                      146
# Manchester United           19
# Manchester City             18
# Chelsea FC                  16
# Paris Saint-Germain         16
# Tottenham Hotspur           16
# Real Madrid                 16
# Arsenal FC                  15
# Atlético de Madrid          15
# Liverpool FC                15
# RB Leipzig                  15
# Bayern Munich               14
# Juventus FC                 13
# AC Milan                    13
# Everton FC                  13
# Leicester City              12
# Atalanta BC                 12
# Aston Villa                 11
# Borussia Dortmund           11
# Wolverhampton Wanderers     11
# FC Barcelona                11
# SSC Napoli                  10
# Real Sociedad                9
# AS Roma                      9
# AS Monaco                    8
# Inter Milan                  8
# West Ham United              7
# LOSC Lille                   7
# Olympique Lyon               7
# Olympique Marseille          7
# ...

# %%
counts2=df_tmp['Club'].value_counts()

plt.figure(figsize=(10, 20)) 
sns.barplot(x=counts2.values, y=counts2.index)  
plt.xlabel("Kaç tane")
plt.ylabel("Club ismi")
plt.title("oyuncuların kuluplere dağılımı")
plt.tight_layout()
plt.show()

# %%
cat_uniques_tmp = {
    label: df_tmp[label].nunique()
    for label, content in df_tmp.items()
    if not pd.api.types.is_numeric_dtype(content)
}


cat_uniques_df_tmp = pd.DataFrame(list(cat_uniques_tmp.items()), columns=["Column", "Unique Count"])
print(cat_uniques_df_tmp)
# Out:
#      Column  Unique Count
# 0  Position            13
# 1   Country            57
# 2      Club            30

# %%
counts_country=df_tmp['Country'].value_counts()
plt.figure(figsize=(10,10))
sns.barplot(x=counts_country.values,y=counts_country.index)
# Out:
# <Axes: ylabel='Country'>

# %%
column_name = 'Country'
threshold = 3


df_tmp[column_name] = df_tmp[column_name].astype(str)


value_counts = df_tmp[column_name].value_counts()


to_replace = value_counts[value_counts < threshold].index


df_tmp[column_name] = df_tmp[column_name].replace(to_replace, 'Other')


print(df_tmp[column_name].value_counts())
# Out:
# Country
# England          67
# France           58
# Spain            52
# Brazil           41
# Other            35
# Germany          29
# Portugal         26
# Italy            26
# Argentina        22
# Netherlands      17
# Belgium          14
# Uruguay          11
# Cote d'Ivoire     8
# Croatia           8
# Nigeria           7
# Denmark           7
# Colombia          7
# Turkey            6
# Senegal           6
# Switzerland       6
# Austria           6
# Serbia            5
# United States     5
# Scotland          5
# Poland            5
# Algeria           4
# Morocco           4
# Sweden            4
# Norway            3
# Mexico            3
# Ukraine           3
# Name: count, dtype: int64

# %%
df_tmp['Country'] = df_tmp['Country'].astype('category')

# %%
df_tmp['Club'] = df_tmp['Club'].astype('category')

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Position                  500 non-null    category
#  1   Age                       500 non-null    int64
#  2   market_value              500 non-null    float64
#  3   Country                   500 non-null    category
#  4   Club                      500 non-null    category
#  5   Matches                   500 non-null    int64
#  6   Goals                     500 non-null    int64
#  7   Own Goals                 500 non-null    int64
#  8   Assists                   500 non-null    int64
#  9   Yellow Cards              500 non-null    int64
#  10  Second Yellow Cards       500 non-null    int64
#  11  Red Cards                 500 non-null    int64
#  12  Number Of Substitute In   500 non-null    int64
# ...

# %%
cat_uniques3 = {
    label: df_tmp[label].nunique()
    for label, content in df_tmp.items()
    if not pd.api.types.is_numeric_dtype(content)
}


cat_uniques_df3 = pd.DataFrame(list(cat_uniques3.items()), columns=["Column", "Unique Count"])
print(cat_uniques_df3)
# Out:
#      Column  Unique Count
# 0  Position            13
# 1   Country            31
# 2      Club            30

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x=df_tmp.Position,y=df_tmp.market_value)
plt.xticks(rotation=45, ha='right')  # 45 derece açı + sağa yasla
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.boxplot(x=df_tmp.Country,y=df_tmp.market_value)
plt.xticks(rotation=45, ha='right')  # 45 derece açı + sağa yasla
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.boxplot(x=df_tmp.Club,y=df_tmp.market_value)
plt.xticks(rotation=45, ha='right')  # 45 derece açı + sağa yasla
plt.tight_layout()
plt.show()

# %%
df_encoded=pd.get_dummies(df_tmp, columns=['Club', 'Country', 'Position'])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Position                  500 non-null    category
#  1   Age                       500 non-null    int64
#  2   market_value              500 non-null    float64
#  3   Country                   500 non-null    category
#  4   Club                      500 non-null    category
#  5   Matches                   500 non-null    int64
#  6   Goals                     500 non-null    int64
#  7   Own Goals                 500 non-null    int64
#  8   Assists                   500 non-null    int64
#  9   Yellow Cards              500 non-null    int64
#  10  Second Yellow Cards       500 non-null    int64
#  11  Red Cards                 500 non-null    int64
#  12  Number Of Substitute In   500 non-null    int64
# ...

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.max_colwidth')

# %%
print(df_encoded.columns)
# Out:
# Index(['Age', 'market_value', 'Matches', 'Goals', 'Own Goals', 'Assists',
#        'Yellow Cards', 'Second Yellow Cards', 'Red Cards',
#        'Number Of Substitute In', 'Number Of Substitute Out', 'Club_AC Milan',
#        'Club_AS Monaco', 'Club_AS Roma', 'Club_Arsenal FC', 'Club_Aston Villa',
#        'Club_Atalanta BC', 'Club_Atlético de Madrid', 'Club_Bayern Munich',
#        'Club_Borussia Dortmund', 'Club_Chelsea FC', 'Club_Everton FC',
#        'Club_FC Barcelona', 'Club_Inter Milan', 'Club_Juventus FC',
#        'Club_LOSC Lille', 'Club_Leicester City', 'Club_Liverpool FC',
#        'Club_Manchester City', 'Club_Manchester United', 'Club_Olympique Lyon',
#        'Club_Olympique Marseille', 'Club_Other', 'Club_Paris Saint-Germain',
#        'Club_RB Leipzig', 'Club_Real Madrid', 'Club_Real Sociedad',
#        'Club_SSC Napoli', 'Club_Tottenham Hotspur', 'Club_West Ham United',
#        'Club_Wolverhampton Wanderers', 'Country_Algeria', 'Country_Argentina',
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(df_encoded.market_value,bins=60,kde=True)           
plt.title("DISTRIBUTION OF MARKET PRICES")
plt.xlabel("market price")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# * This function has 2 parameters that data and label and calculates mutual information between them

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X,y):
    mi_scores=mutual_info_regression(X,y)
    mi_scores=pd.Series(mi_scores,name='MI_SCORES',index=X.columns)
    mi_scores=mi_scores.sort_values(ascending=False)
    return mi_scores

# %%
mi_scores=make_mi_scores(df_encoded.drop("market_value",axis=1),df_encoded["market_value"])

# %%
mi_scores
# Out:
# Club_Manchester City            0.059959
# Club_Other                      0.047844
# Country_Senegal                 0.043672
# Club_Wolverhampton Wanderers    0.042137
# Club_Everton FC                 0.040477
#                                   ...
# Position_Left Midfield          0.000000
# Position_Left-Back              0.000000
# Position_Left Winger            0.000000
# Position_Right Midfield         0.000000
# Position_Second Striker         0.000000
# Name: MI_SCORES, Length: 84, dtype: float64

# %% [markdown]
# * This function plots the mutual_info

# %%
def mi_score_plot(mi_score):
    plt.figure(figsize=(6,(0.25)*len(mi_score)))
    mi_score.plot(kind="barh",color="royalblue")
    plt.xlabel("Mutual Information Score")
    plt.ylabel("Features")
    plt.title("Mutual Information Scores")
    plt.gca().invert_yaxis()
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    
    

mi_score_plot(mi_scores)

# %% [markdown]
# * See how related the 2 most related columns

# %%
fig, axes=plt.subplots(1,2,figsize=(14,6))
sns.scatterplot(x=df_encoded.Club_Other,y=df_encoded.market_value,ax=axes[0])
axes[0].set_title("Club_Other - market_value")
sns.scatterplot(x=df_encoded.Goals,y=df_encoded.market_value,ax=axes[1])
axes[1].set_title("Goals - market_value")
# Out:
# Text(0.5, 1.0, 'Goals - market_value')

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 85 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           500 non-null    int64
#  1   market_value                  500 non-null    float64
#  2   Matches                       500 non-null    int64
#  3   Goals                         500 non-null    int64
#  4   Own Goals                     500 non-null    int64
#  5   Assists                       500 non-null    int64
#  6   Yellow Cards                  500 non-null    int64
#  7   Second Yellow Cards           500 non-null    int64
#  8   Red Cards                     500 non-null    int64
#  9   Number Of Substitute In       500 non-null    int64
#  10  Number Of Substitute Out      500 non-null    int64
#  11  Club_AC Milan                 500 non-null    bool
#  12  Club_AS Monaco                500 non-null    bool
# ...

# %% [markdown]
# ## End of Project
#
# * Project ends here because there cant be found any reasonable relationship between columns.Closestt column is mutual with market_value at 0.06 which is very low for to find relationships between label.But in this project We analyzed 500 of the highest valued footballers from 2021 and we can say clearly say that spesific Club,Country,Age has no strong effect in market_value.But also we should say we have worked with 500 footballer data maybe if we did have all the footballers we could say the otherwise
